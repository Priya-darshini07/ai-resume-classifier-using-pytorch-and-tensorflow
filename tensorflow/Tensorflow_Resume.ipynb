# %%
# ============================================
# TensorFlow Resume Text Classifier (Complete)
# ============================================

# 1. Import Libraries
import tensorflow as tf
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

print("TensorFlow version:", tf.__version__)

# ============================================
# 2. Dataset
# ============================================

texts = [
    "Experienced Python developer with knowledge of data structures",
    "Worked with pandas numpy and machine learning models",
    "Built deep learning models using pytorch and tensorflow",
    "Designed responsive websites using HTML CSS JavaScript",
    "Developed REST APIs using FastAPI and Django",
    "Performed data analysis and visualization using matplotlib",
    "Implemented CNNs and NLP models for AI applications",
    "Created frontend applications using React and Bootstrap"
]

labels = [
    0,  # Software Development
    1,  # Data Science
    2,  # AI / ML
    3,  # Web Development
    0,
    1,
    2,
    3
]

# ============================================
# 3. Text → Numerical Features (Bag of Words)
# ============================================

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texts).toarray()

X = np.array(X, dtype=np.float32)
y = np.array(labels, dtype=np.int32)

print("Feature matrix shape:", X.shape)
print("Labels shape:", y.shape)

# ============================================
# 4. Build TensorFlow Model (Keras)
# ============================================

model = tf.keras.Sequential([
    tf.keras.layers.Dense(
        64,
        activation='relu',
        input_shape=(X.shape[1],)
    ),
    tf.keras.layers.Dense(4)  # logits (no softmax)
])

model.summary()

# ============================================
# 5. Compile Model
# ============================================

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# ============================================
# 6. Train Model
# ============================================

history = model.fit(
    X,
    y,
    epochs=50,
    verbose=1
)

# ============================================
# 7. Prediction Function
# ============================================

label_map = {
    0: "Software Development",
    1: "Data Science",
    2: "AI / ML",
    3: "Web Development"
}

def predict(text):
    vec = vectorizer.transform([text]).toarray()
    logits = model(vec)
    prediction = tf.argmax(logits, axis=1).numpy()[0]
    return label_map[prediction]

# ============================================
# 8. Test the Model
# ============================================

test_sentences = [
    "Experienced in neural networks and deep learning",
    "Strong skills in pandas numpy and data visualization",
    "Built backend REST APIs using Django and FastAPI",
    "Designed responsive UI using HTML CSS JavaScript"
]

for text in test_sentences:
    print("Text:", text)
    print("Predicted Category:", predict(text))
    print("-" * 60)
# Out:
# TensorFlow version: 2.19.0
# Feature matrix shape: (8, 45)
# Labels shape: (8,)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         2,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,204 (12.52 KB)
#  Trainable params: 3,204 (12.52 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2500 - loss: 1.3354
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3750 - loss: 1.3002
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3750 - loss: 1.2656
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.3750 - loss: 1.2316
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6250 - loss: 1.1982
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.7500 - loss: 1.1655
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7500 - loss: 1.1334
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8750 - loss: 1.1019
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8750 - loss: 1.0711
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8750 - loss: 1.0411
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8750 - loss: 1.0119
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8750 - loss: 0.9833
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8750 - loss: 0.9554
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.9283
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.9019
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.8761
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.8511
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.8266
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.8027
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.7794
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.7568
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 1.0000 - loss: 0.7347
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.7130
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.6921
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.6716
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.6516
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.6320
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.6129
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.5940
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.5756
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.5576
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.5401
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.5231
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.5066
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.4906
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.4751
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.4600
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.4454
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.4312
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.4174
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.4041
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.3912
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.3785
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.3662
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.3542
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.3426
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.3313
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.3204
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 0.3098
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.2996
# Text: Experienced in neural networks and deep learning
# Predicted Category: AI / ML
# ------------------------------------------------------------
# Text: Strong skills in pandas numpy and data visualization
# Predicted Category: Data Science
# ------------------------------------------------------------
# Text: Built backend REST APIs using Django and FastAPI
# Predicted Category: Software Development
# ------------------------------------------------------------
# Text: Designed responsive UI using HTML CSS JavaScript
# Predicted Category: Web Development
# ------------------------------------------------------------
